# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from read_data import read_data_hsa

# %%
data_TPM = read_data_hsa('TPM')
data_TPM
#### pre-processing
data_TPM_filtered1 = data_TPM.loc[data_TPM.max(axis=1) > 1]

sns.heatmap(data_TPM_filtered1.corr(),annot=True,square=True,cmap='RdBu_r')
# Out:
# <AxesSubplot:>

# %%
select_gene_list = ['AFP','GPC3','ALB','TTR','APOA1','APOE','CYP2D6','FGA','FGG',
                    'EPCAM','PROM1','KRT19','S100A11','S100A6','ALDOA','CLIC3'
                    ]
sl = [i for i in data_TPM.index if i in select_gene_list]
data_TPM_filtered2 = data_TPM.loc[sl,:]
sns.set_theme(color_codes=True)
ax = sns.clustermap(np.log2(data_TPM_filtered2+1),yticklabels=True,cmap='RdBu_r')
